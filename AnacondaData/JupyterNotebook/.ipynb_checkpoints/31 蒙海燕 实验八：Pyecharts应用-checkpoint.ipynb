# %%
# 导包
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from pylab import mpl
from pyecharts import options as opts
from pyecharts.charts import Bar,Line,Pie,Tab
from pyecharts.globals import ThemeType

# 设置显示中文字体
mpl.rcParams["font.sans-serif"] = ["SimHei"]
# 设置正常显示符号
mpl.rcParams["axes.unicode_minus"] = False

# %%
#1.引入tsv文件
df = pd.read_csv(r'5月14日\gapminder.tsv',sep='\t',header=0)
df.head
# Out:
# <bound method NDFrame.head of           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]>

# %% [markdown]
# # 一.绘制条形图，统计不同大陆的国家数量。

# %%
#value_counts()
#2.不同大陆
continents = df["continent"].unique().tolist()
continents
# Out:
# ['Asia', 'Europe', 'Africa', 'Americas', 'Oceania']

# %%
#3.不同大陆的数量
continent_counts = df.groupby("continent")["country"].nunique().tolist()
print("数量：\n",continent_counts,"\n","--"*10)
continent_counts = df.groupby("continent")["country"].nunique()
print("不同大陆数量：\n",continent_counts,"\n","--"*10)
#重置数据帧的索引，并使用默认索引。如果数据帧具有多重索引，则此方法可以删除一个或多个level。
continent_counts = continent_counts.reset_index()
print("添加索引后的不同大陆数量：\n",continent_counts,"\n","--"*10)
# Out:
# 数量：
#  [52, 25, 33, 30, 2]
#  --------------------
# 不同大陆数量：
#  continent
# Africa      52
# Americas    25
# Asia        33
# Europe      30
# Oceania      2
# Name: country, dtype: int64
#  --------------------
# 添加索引后的不同大陆数量：
#    continent  country
# 0    Africa       52
# 1  Americas       25
# 2      Asia       33
# 3    Europe       30
# 4   Oceania        2
#  --------------------

# %%
#4.创建一个字典
continent_num = {
    "Africa":1,
    "Americas":2,
    "Asia":3,
    "Europe":4,
    "Oceania":5,
}
continent_num
# Out:
# {'Africa': 1, 'Americas': 2, 'Asia': 3, 'Europe': 4, 'Oceania': 5}

# %%
#5.根据字典对应的continent排序
df['continent_num'] = df['continent'].map(continent_num)
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap  continent_num
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314              3
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030              3
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710              3
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138              3
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106              3

# %%
#6.对continent不同大陆的数量进行分组
#y_line = df.groupby('continent')['continent_num'].unique().sum()
y_line = df.groupby("continent_num")['country'].nunique()
y_line = y_line.reset_index()
y_line
# Out:
#    continent_num  country
# 0              1       52
# 1              2       25
# 2              3       33
# 3              4       30
# 4              5        2

# %%
#7.绘制条形图
bar_continent = Bar(init_opts = 
          opts.InitOpts(width='500px',
                        height="300px",
                       theme = ThemeType.VINTAGE,
                        #动画
                        animation_opts= opts.AnimationOpts(
                                        animation = True,                                        
                                        animation_duration = 1000,#持续时间
                                        animation_delay = 300,#延迟
                                        animation_easing = "elasticOut"#动画方式
                                    )
                        )
         )
continents=['Africa', 'Americas', 'Asia', 'Europe', 'Oceania']
bar_continent.add_xaxis(continents)
bar_continent.add_yaxis(series_name = "该大陆国家数量",
            # y_axis = continent_counts
            y_axis = np.round(y_line['country'],0).tolist()#国家数量
             )
bar_continent.set_global_opts(title_opts =
                    opts.TitleOpts(
                        title = "不同大陆的国家数量"
                        ),                    
                     toolbox_opts = opts.ToolboxOpts(is_show =True),#工具箱
                     datazoom_opts = opts.DataZoomOpts(is_show=True,type_='slider')#数据缩放
                    )

bar_continent.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'vintage':'https://assets.pyecharts.org/assets/v5/themes/vintage'
#         }
#     });
# </script>
#
#         <div id="bf46831a8ce54283acbf5ebbaeab8188" style="width:500px; height:300px;"></div>
#
# <script>
#         require(['echarts', 'vintage'], function(echarts) {
#                 var chart_bf46831a8ce54283acbf5ebbaeab8188 = echarts.init(
#                     document.getElementById('bf46831a8ce54283acbf5ebbaeab8188'), 'vintage', {renderer: 'canvas'});
#                 var option_bf46831a8ce54283acbf5ebbaeab8188 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "elasticOut",
#     "animationDelay": 300,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u8be5\u5927\u9646\u56fd\u5bb6\u6570\u91cf",
#             "legendHoverLink": true,
#             "data": [
#                 52,
#                 25,
#                 33,
#                 30,
#                 2
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u8be5\u5927\u9646\u56fd\u5bb6\u6570\u91cf"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "Africa",
#                 "Americas",
#                 "Asia",
#                 "Europe",
#                 "Oceania"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u4e0d\u540c\u5927\u9646\u7684\u56fd\u5bb6\u6570\u91cf",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "horizontal",
#         "itemSize": 15,
#         "itemGap": 10,
#         "left": "80%",
#         "feature": {
#             "saveAsImage": {
#                 "type": "png",
#                 "backgroundColor": "auto",
#                 "connectedBackgroundColor": "#fff",
#                 "show": true,
#                 "title": "\u4fdd\u5b58\u4e3a\u56fe\u7247",
#                 "pixelRatio": 1
#             },
#             "restore": {
#                 "show": true,
#                 "title": "\u8fd8\u539f"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "\u6570\u636e\u89c6\u56fe",
#                 "readOnly": false,
#                 "lang": [
#                     "\u6570\u636e\u89c6\u56fe",
#                     "\u5173\u95ed",
#                     "\u5237\u65b0"
#                 ],
#                 "backgroundColor": "#fff",
#                 "textareaColor": "#fff",
#                 "textareaBorderColor": "#333",
#                 "textColor": "#000",
#                 "buttonColor": "#c23531",
#                 "buttonTextColor": "#fff"
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "zoom": "\u533a\u57df\u7f29\u653e",
#                     "back": "\u533a\u57df\u7f29\u653e\u8fd8\u539f"
#                 },
#                 "icon": {},
#                 "filterMode": "filter"
#             },
#             "magicType": {
#                 "show": true,
#                 "type": [
#                     "line",
#                     "bar",
#                     "stack",
#                     "tiled"
#                 ],
#                 "title": {
#                     "line": "\u5207\u6362\u4e3a\u6298\u7ebf\u56fe",
#                     "bar": "\u5207\u6362\u4e3a\u67f1\u72b6\u56fe",
#                     "stack": "\u5207\u6362\u4e3a\u5806\u53e0",
#                     "tiled": "\u5207\u6362\u4e3a\u5e73\u94fa"
#                 },
#                 "icon": {}
#             }
#         }
#     },
#     "dataZoom": {
#         "show": true,
#         "type": "slider",
#         "showDetail": true,
#         "showDataShadow": true,
#         "realtime": true,
#         "start": 20,
#         "end": 80,
#         "orient": "horizontal",
#         "zoomLock": false,
#         "filterMode": "filter"
#     }
# };
#                 chart_bf46831a8ce54283acbf5ebbaeab8188.setOption(option_bf46831a8ce54283acbf5ebbaeab8188);
#         });
#     </script>

# %% [markdown]
# # 二.绘制折线图，统计不同时期平均GDP和平均寿命情况（进阶：统计不同大陆在不同时间的平均GDP和平均寿命情况）。

# %%
#2.分组：不同时期平均GDP和平均寿命
year_mean = df.groupby("year")[["gdpPercap","lifeExp"]].mean()
year_mean
# Out:
#          gdpPercap    lifeExp
# year
# 1952   3725.276046  49.057620
# 1957   4299.408345  51.507401
# 1962   4725.812342  53.609249
# 1967   5483.653047  55.678290
# 1972   6770.082815  57.647386
# 1977   7313.166421  59.570157
# 1982   7518.901673  61.533197
# 1987   7900.920218  63.212613
# 1992   8158.608521  64.160338
# 1997   9090.175363  65.014676
# 2002   9917.848365  65.694923
# 2007  11680.071820  67.007423

# %%
#3.绘制折线图
line_year = Line(init_opts = 
          opts.InitOpts(width='800px',
                        height="400px",
                       theme = ThemeType.VINTAGE,
                        #动画
                        animation_opts= opts.AnimationOpts(
                                        animation = True,                                        
                                        animation_duration = 1000,#持续时间
                                        animation_delay = 300,#延迟
                                        animation_easing = "elasticOut"#动画方式
                                    )
                        )
         )
years=['1952','1957','1962','1967','1972','1977','1982','1987','1992','1997','2002','2007']
line_year.add_xaxis(years)
line_year.add_yaxis(series_name = "gdpPercap平均值",
            # y_axis = continent_counts
            y_axis = np.round(year_mean['gdpPercap'],2).tolist()#gdp平均
             )
line_year.add_yaxis(series_name = "lifeExp平均值",
            # y_axis = continent_counts
            y_axis = np.round(year_mean['lifeExp'],1).tolist()#生命平均值
             )
line_year.set_global_opts(title_opts =
                    opts.TitleOpts(
                        title = "不同大陆的国家数量"
                        ),                    
                     toolbox_opts = opts.ToolboxOpts(is_show =True),#工具箱
                     datazoom_opts = opts.DataZoomOpts(is_show=True,type_='slider')#数据缩放
                    )

line_year.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'vintage':'https://assets.pyecharts.org/assets/v5/themes/vintage'
#         }
#     });
# </script>
#
#         <div id="9d6a151e4199451cbef73b5e44d5837e" style="width:800px; height:400px;"></div>
#
# <script>
#         require(['echarts', 'vintage'], function(echarts) {
#                 var chart_9d6a151e4199451cbef73b5e44d5837e = echarts.init(
#                     document.getElementById('9d6a151e4199451cbef73b5e44d5837e'), 'vintage', {renderer: 'canvas'});
#                 var option_9d6a151e4199451cbef73b5e44d5837e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "elasticOut",
#     "animationDelay": 300,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "gdpPercap\u5e73\u5747\u503c",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "1952",
#                     3725.28
#                 ],
#                 [
#                     "1957",
#                     4299.41
#                 ],
#                 [
#                     "1962",
#                     4725.81
#                 ],
#                 [
#                     "1967",
#                     5483.65
#                 ],
#                 [
#                     "1972",
#                     6770.08
#                 ],
#                 [
#                     "1977",
#                     7313.17
#                 ],
#                 [
#                     "1982",
#                     7518.9
#                 ],
#                 [
#                     "1987",
#                     7900.92
#                 ],
#                 [
#                     "1992",
#                     8158.61
#                 ],
#                 [
#                     "1997",
#                     9090.18
#                 ],
#                 [
#                     "2002",
#                     9917.85
#                 ],
#                 [
#                     "2007",
#                     11680.07
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "lifeExp\u5e73\u5747\u503c",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "1952",
#                     49.1
#                 ],
#                 [
#                     "1957",
#                     51.5
#                 ],
#                 [
#                     "1962",
#                     53.6
#                 ],
#                 [
#                     "1967",
#                     55.7
#                 ],
#                 [
#                     "1972",
#                     57.6
#                 ],
#                 [
#                     "1977",
#                     59.6
#                 ],
#                 [
#                     "1982",
#                     61.5
#                 ],
#                 [
#                     "1987",
#                     63.2
#                 ],
#                 [
#                     "1992",
#                     64.2
#                 ],
#                 [
#                     "1997",
#                     65.0
#                 ],
#                 [
#                     "2002",
#                     65.7
#                 ],
#                 [
#                     "2007",
#                     67.0
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "gdpPercap\u5e73\u5747\u503c",
#                 "lifeExp\u5e73\u5747\u503c"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "1952",
#                 "1957",
#                 "1962",
#                 "1967",
#                 "1972",
#                 "1977",
#                 "1982",
#                 "1987",
#                 "1992",
#                 "1997",
#                 "2002",
#                 "2007"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u4e0d\u540c\u5927\u9646\u7684\u56fd\u5bb6\u6570\u91cf",
#             "target": "blank",
#             "subtarget": "blank",

# %%
#4-1.进阶：统计不同大陆在不同时间的平均GDP和平均寿命情况）
continent_year = df.groupby(["year","continent"])[["gdpPercap","lifeExp"]].mean()
continent_year =continent_year.reset_index()
#print(type(continent_year))
#print(continent_year)
# 设置X轴（年份）和分组依据（大陆）  
years = continent_year['year'].unique()  
continents = continent_year['continent'].unique()

# %%
#小验证：
year_1952 = df[df["year"]==1952].groupby("continent")['gdpPercap'].mean()
year_1952
index = pd.MultiIndex.from_product([continents, years], names=['continent', 'year'])
#index

# %%
#4-2.绘制折线图

# 初始化Line对象  
line = Line(init_opts = 
          opts.InitOpts(width='900px',
                        height="500px",
                       theme = ThemeType.VINTAGE)
           )
line.add_xaxis(years.tolist())  
#为每个大陆添加GDP和平均寿命序列  
for continent in continents:  
    continent_df = continent_year[continent_year['continent'] == continent]  
    gdp_data = np.round(continent_df['gdpPercap'],2).tolist()  
    life_expectancy_data = np.round(continent_df['lifeExp'],2).tolist()     
    line.add_yaxis(f"{continent} 平均GDP", gdp_data, label_opts=opts.LabelOpts(is_show=False))  
      
    # 如果需要第二个Y轴来显示平均寿命  
    if continent == continents[0]:  # 只为第一个大陆添加第二个Y轴作为示例  
        line.extend_axis(  
            yaxis=opts.AxisOpts(  
                name="平均GDP、寿命",
                type_="value",  
                position="right",  
                axisline_opts=opts.AxisLineOpts(linestyle_opts=opts.LineStyleOpts(color="#d14a61"))  
            )  
        )  
        line.set_series_opts(yaxis_index=1, label_opts=opts.LabelOpts(formatter="{value}", position="right"))  
    line.add_yaxis(f"{continent} 平均寿命", life_expectancy_data, yaxis_index=1, label_opts=opts.LabelOpts(is_show=False))  
  
 # 置全局配置项（可选）  
line.set_global_opts( 
    legend_opts=opts.LegendOpts(# 图例位置，配置方法与标题相同
        pos_right='20%',pos_top='25', # 图例布局朝向：'horizontal'(默认，横排)
        orient='horizontal',align='auto',item_gap=10),
    title_opts=opts.TitleOpts(title="不同大陆与时间间的平均GDP、寿命情况",pos_top=5),  
    tooltip_opts=opts.TooltipOpts(trigger="axis", axis_pointer_type="cross"),  
    #legend_opts=opts.LegendOpts(orient="vertical", pos_top="15%", pos_left="2%"),
    toolbox_opts = opts.ToolboxOpts(is_show =True),#工具箱
    datazoom_opts = opts.DataZoomOpts(is_show=True,type_='slider'),#数据缩放
    visualmap_opts=opts.VisualMapOpts(
            # 是否显示视觉映射配置
            is_show = True,type_ = "color",min_ = 0,
            max_ = 200,
            range_text = ['高', '低'],
            range_color = ['#32CD32','#00FF7F','#87CEFA','#48D1CC','#BA55D3','#DB7093'],
            range_size = None,
            range_opacity = None,
            orient = 'vertical'
    )
)  
# 渲染图表到HTML文件  
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'vintage':'https://assets.pyecharts.org/assets/v5/themes/vintage'
#         }
#     });
# </script>
#
#         <div id="3a77dc1b5ccb454d8ba1272a2a296e6c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'vintage'], function(echarts) {
#                 var chart_3a77dc1b5ccb454d8ba1272a2a296e6c = echarts.init(
#                     document.getElementById('3a77dc1b5ccb454d8ba1272a2a296e6c'), 'vintage', {renderer: 'canvas'});
#                 var option_3a77dc1b5ccb454d8ba1272a2a296e6c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "Africa \u5e73\u5747GDP",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     1952,
#                     1252.57
#                 ],
#                 [
#                     1957,
#                     1385.24
#                 ],
#                 [
#                     1962,
#                     1598.08
#                 ],
#                 [
#                     1967,
#                     2050.36
#                 ],
#                 [
#                     1972,
#                     2339.62
#                 ],
#                 [
#                     1977,
#                     2585.94
#                 ],
#                 [
#                     1982,
#                     2481.59
#                 ],
#                 [
#                     1987,
#                     2282.67
#                 ],
#                 [
#                     1992,
#                     2281.81
#                 ],
#                 [
#                     1997,
#                     2378.76
#                 ],
#                 [
#                     2002,
#                     2599.39
#                 ],
#                 [
#                     2007,
#                     3089.03
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8,
#                 "formatter": "{value}"
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0,
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "yaxis_index": 1
#         },
#         {
#             "type": "line",
#             "name": "Africa \u5e73\u5747\u5bff\u547d",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "yAxisIndex": 1,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     1952,
#                     39.14
#                 ],
#                 [
#                     1957,
#                     41.27
#                 ],
#                 [
#                     1962,
#                     43.32
#                 ],
#                 [
#                     1967,
#                     45.33
#                 ],
#                 [
#                     1972,
#                     47.45
#                 ],
#                 [
#                     1977,
#                     49.58
#                 ],
#                 [
#                     1982,
#                     51.59
#                 ],
#                 [
#                     1987,
#                     53.34
#                 ],
#                 [
#                     1992,
#                     53.63
#                 ],
#                 [
#                     1997,
#                     53.6
#                 ],
#                 [
#                     2002,
#                     53.33
#                 ],
#                 [
#                     2007,
#                     54.81
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "Americas \u5e73\u5747GDP",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     1952,
#                     4079.06
#                 ],
#                 [
#                     1957,
#                     4616.04
#                 ],
#                 [
#                     1962,
#                     4901.54
#                 ],
#                 [
#                     1967,
#                     5668.25
#                 ],
#                 [
#                     1972,
#                     6491.33
#                 ],
#                 [
#                     1977,
#                     7352.01
#                 ],
#                 [
#                     1982,
#                     7506.74
#                 ],
#                 [
#                     1987,
#                     7793.4
#                 ],
#                 [
#                     1992,
#                     8044.93
#                 ],
#                 [
#                     1997,
#                     8889.3
#                 ],
#                 [
#                     2002,
#                     9287.68
#                 ],
#                 [
#                     2007,
#                     11003.03
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "Americas \u5e73\u5747\u5bff\u547d",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "yAxisIndex": 1,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     1952,
#                     53.28
#                 ],
#                 [
#                     1957,
#                     55.96
#                 ],
#                 [
#                     1962,
#                     58.4
#                 ],
#                 [
#                     1967,
#                     60.41
#                 ],
#                 [
#                     1972,
#                     62.39
#                 ],
#                 [
#                     1977,
#                     64.39
#                 ],
#                 [
#                     1982,

# %% [markdown]
# # 三.绘制饼图，统计2007年不同大陆人口占比情况

# %%
#切片2007年大陆人口
pop2007=df.loc[df["year"]==2007,["continent","pop"]]
pop2007
# Out:
#      continent       pop
# 11        Asia  31889923
# 23      Europe   3600523
# 35      Africa  33333216
# 47      Africa  12420476
# 59    Americas  40301927
# ...        ...       ...
# 1655      Asia  85262356
# 1667      Asia   4018332
# 1679      Asia  22211743
# 1691    Africa  11746035
# 1703    Africa  12311143
#
# [142 rows x 2 columns]

# %%
#2007年不同大陆的总人口
cont2007pop=pop2007.groupby("continent")["pop"].sum()
cont2007pop
# cont2007pop = cont2007pop.reset_index()
# cont2007pop
# Out:
# continent
# Africa       929539692
# Americas     898871184
# Asia        3811953827
# Europe       586098529
# Oceania       24549947
# Name: pop, dtype: int64

# %%
#转list
c_index=list(cont2007pop.index)
c_values=list(cont2007pop.values)
#统计人数
c_sum=sum(c_values)
print(c_sum)
c_zip=list(zip(c_index,c_values))
print(c_zip)
# Out:
# 6251013179
# [('Africa', 929539692), ('Americas', 898871184), ('Asia', 3811953827), ('Europe', 586098529), ('Oceania', 24549947)]

# %%
pie= Pie(init_opts = opts.InitOpts
          (width='600px',
           height='400px',
           theme = ThemeType.VINTAGE,
           animation_opts=opts.AnimationOpts(
                          animation = True,
                          animation_duration =1000,
                          animation_delay = 300,
                          animation_easing = 'cubicOut'))
        )
# pie 数据添加需要data pair [(男,200),(女,200)]
pie.add("",[('Africa', 929539692), ('Americas', 898871184), ('Asia', 3811953827), ('Europe', 586098529), ('Oceania', 24549947)])
pie.set_global_opts(title_opts = opts.TitleOpts(
                    title = "2007年不同大陆人口占比"))
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'vintage':'https://assets.pyecharts.org/assets/v5/themes/vintage'
#         }
#     });
# </script>
#
#         <div id="352bcda6228c429ca1c5d2c6df0fa4e0" style="width:600px; height:400px;"></div>
#
# <script>
#         require(['echarts', 'vintage'], function(echarts) {
#                 var chart_352bcda6228c429ca1c5d2c6df0fa4e0 = echarts.init(
#                     document.getElementById('352bcda6228c429ca1c5d2c6df0fa4e0'), 'vintage', {renderer: 'canvas'});
#                 var option_352bcda6228c429ca1c5d2c6df0fa4e0 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 300,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "Africa",
#                     "value": 929539692
#                 },
#                 {
#                     "name": "Americas",
#                     "value": 898871184
#                 },
#                 {
#                     "name": "Asia",
#                     "value": 3811953827
#                 },
#                 {
#                     "name": "Europe",
#                     "value": 586098529
#                 },
#                 {
#                     "name": "Oceania",
#                     "value": 24549947
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Africa",
#                 "Americas",
#                 "Asia",
#                 "Europe",
#                 "Oceania"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "2007\u5e74\u4e0d\u540c\u5927\u9646\u4eba\u53e3\u5360\u6bd4",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ]
# };
#                 chart_352bcda6228c429ca1c5d2c6df0fa4e0.setOption(option_352bcda6228c429ca1c5d2c6df0fa4e0);
#         });
#     </script>

# %% [markdown]
# # 四.将上面三个图运用Tab进行组合。

# %%
tab = Tab()  
tab.add(bar_continent, "条形图")  
tab.add(line_year, "折线图")  
tab.add(pie, "饼图")
tab.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'vintage':'https://assets.pyecharts.org/assets/v5/themes/vintage'
#         }
#     });
# </script>
#
#     <style>
#         .tab {
#             overflow: hidden;
#             border: 1px solid #ccc;
#             background-color: #f1f1f1;
#         }
#
#         .tab button {
#             background-color: inherit;
#             float: left;
#             border: none;
#             outline: none;
#             cursor: pointer;
#             padding: 12px 16px;
#             transition: 0.3s;
#         }
#
#         .tab button:hover {
#             background-color: #ddd;
#         }
#
#         .tab button.active {
#             background-color: #ccc;
#         }
#
#         .chart-container {
#             display: block;
#         }
#
#         .chart-container:nth-child(n+2) {
#             display: none;
#         }
#     </style>
# <div class="tab">
#             <button class="tablinks" onclick="showChart(event, 'fee44a055895499883e9c17d06dea114')">条形图</button>
#             <button class="tablinks" onclick="showChart(event, 'b9e92e7a6fd84411a69505128ad1bfc9')">折线图</button>
#             <button class="tablinks" onclick="showChart(event, 'dfb1b0e96d8c4c38a994df8c89de3873')">饼图</button>
#     </div>
#
#         <div id="fee44a055895499883e9c17d06dea114" class="chart-container" style="width:500px; height:300px;"></div>
#         <div id="b9e92e7a6fd84411a69505128ad1bfc9" class="chart-container" style="width:500px; height:300px;"></div>
#         <div id="dfb1b0e96d8c4c38a994df8c89de3873" class="chart-container" style="width:600px; height:400px;"></div>
#
# <script>
#         require(['echarts', 'vintage'], function(echarts) {
#                 var chart_fee44a055895499883e9c17d06dea114 = echarts.init(
#                     document.getElementById('fee44a055895499883e9c17d06dea114'), 'vintage', {renderer: 'canvas'});
#                 var option_fee44a055895499883e9c17d06dea114 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "elasticOut",
#     "animationDelay": 300,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u8be5\u5927\u9646\u56fd\u5bb6\u6570\u91cf",
#             "legendHoverLink": true,
#             "data": [
#                 52,
#                 25,
#                 33,
#                 30,
#                 2
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u8be5\u5927\u9646\u56fd\u5bb6\u6570\u91cf"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "Africa",
#                 "Americas",
#                 "Asia",
#                 "Europe",
#                 "Oceania"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u4e0d\u540c\u5927\u9646\u7684\u56fd\u5bb6\u6570\u91cf",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "horizontal",
#         "itemSize": 15,
#         "itemGap": 10,
#         "left": "80%",
#         "feature": {
#             "saveAsImage": {
#                 "type": "png",
#                 "backgroundColor": "auto",
#                 "connectedBackgroundColor": "#fff",
#                 "show": true,
#                 "title": "\u4fdd\u5b58\u4e3a\u56fe\u7247",
#                 "pixelRatio": 1
#             },
#             "restore": {
#                 "show": true,
#                 "title": "\u8fd8\u539f"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "\u6570\u636e\u89c6\u56fe",
#                 "readOnly": false,
#                 "lang": [
#                     "\u6570\u636e\u89c6\u56fe",
#                     "\u5173\u95ed",
#                     "\u5237\u65b0"
#                 ],
#                 "backgroundColor": "#fff",
#                 "textareaColor": "#fff",
#                 "textareaBorderColor": "#333",
#                 "textColor": "#000",
#                 "buttonColor": "#c23531",
#                 "buttonTextColor": "#fff"
#             },
#             "dataZoom": {
#                 "show": true,
#                 "title": {
#                     "zoom": "\u533a\u57df\u7f29\u653e",
#                     "back": "\u533a\u57df\u7f29\u653e\u8fd8\u539f"
#                 },
#                 "icon": {},
#                 "filterMode": "filter"
#             },
#             "magicType": {
#                 "show": true,
#                 "type": [
#                     "line",
#                     "bar",
#                     "stack",
#                     "tiled"
#                 ],
#                 "title": {
#                     "line": "\u5207\u6362\u4e3a\u6298\u7ebf\u56fe",
